# %%
# %pip install mlflow

# %%
import mlflow.spark
#run_id = 
#"'ffc34363940c4961860521630263d572'


run_id = "a3775cdbba1f4e009c86494a788dcb04"
uri = f"runs:/{run_id}/models/best_model"
spark_model = mlflow.spark.load_model(uri)


#preds = spark_model.transform(test_df)

# %%
#spark_model.stages[-1].feature_names

# %%
input_cols = spark_model.stages[-2].getInputCols()

# %%
feature_importances = spark_model.stages[-1].get_feature_importances()

# %%
named_feature_importances = list(zip(input_cols, feature_importances.values()))

# %%
import pandas as pd
feats = pd.DataFrame(named_feature_importances, columns=['feature_name','feature_importance']).sort_values(by='feature_importance', ascending=False).head(20)

# %%
feats.display()

# %%
latest

# %%
import mlflow
from mlflow.tracking import MlflowClient

run_id = "791f00bec4f94295af559991e5406bf9"

client = MlflowClient()  # on Databricks, tracking URI is set for you
run = client.get_run(run_id)

# Latest metric values (one per metric key)
latest = run.data.metrics           # dict: {metric_key: latest_value}
params = run.data.params            # dict
tags = run.data.tags                # dict

latest


#metric_key = "your_metric_name"
#history = client.get_metric_history(run_id, metric_key)
# history is a list of Metric objects with .step, .value, .timestamp
#[(m.step, m.value, m.timestamp) for m in history]

# %%
spark_model.stages[-1].get_feature_importances()
