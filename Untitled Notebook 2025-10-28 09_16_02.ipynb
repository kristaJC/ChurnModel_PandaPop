# %%
# %pip install mlflow

# %%
import mlflow.spark
run_id = 
'ffc34363940c4961860521630263d572'
uri = f"runs:/{
'ffc34363940c4961860521630263d572'}/models/best_model"
spark_model = mlflow.spark.load_model(uri)


#preds = spark_model.transform(test_df)

# %%
spark_model.__dict__
